# %%
import numpy as np
import matplotlib.pyplot as plt
# NumPy, a popular library for scientific computing
# Matplotlib, a popular library for plotting data

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
i = 1 # Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(1), y^(1)) = (2.0, 500.0)

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    m = x.shape[0] # m is basically the length of the array 
    f_wb = np.full(m,0)
    #The line f_wb = np.zeros(m) is creating a NumPy array named f_wb with m elements, and all elements are initialized to zero.
    for i in range(0,m):
        # i traverses only from 0 to m-1
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)
#calling a fn. which we just created above


# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
w = 200                         
b = 100   
new_estimate=compute_model_output(x_train,w,b)
plt.plot(x_train,new_data,c='b',label='Our Prediction')
plt.scatter(x_train,new_data,marker='x',c='r',label='Actual Values')

plt.title("Housing Prices")
plt.ylabel("Price in (1000s of dollars)")
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
x_i=1.2 # we want to find the price or estimated price of a 1200 sqft. apartment
print((x_i*w) + b)
# Out:
# 340.0
